# %%
import RandTempNet.utils as tnu
import RandTempNet.measures as tnm
import networkx as nx

# %%
tij_data = tnu.read_tij("./data/contact_data/tij_anon_thiers2011.dat")

# %% [markdown]
# # Aggregated network analysis

# %%
len(tij_data.display())
# Out:
# 28540

# %%
G = tnu.aggregate_tij(tij_data)

# %% [markdown]
# ## Density

# %%
nx.density(G)
# Out:
# 0.21714285714285714

# %% [markdown]
# ## Average degree

# %%
nnodes = G.number_of_nodes()
print(sum(d for n, d in G.degree()) / float(nnodes))
# Out:
# 27.142857142857142

# %% [markdown]
# ## Average clustering coefficient

# %%
print(nx.average_clustering(G))
# Out:
# 0.5759076430286774

# %% [markdown]
# # Contact statistics

# %%
tijtau_data = tnu.tij_to_tijtau(tij_data,1,join=True)
lks_data = tnu.tijtau_to_link_timeline(tijtau_data)

# %%
tnm.analysis(lks_data,1,save=False)
